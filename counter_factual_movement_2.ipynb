# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import math
from scipy.spatial import ConvexHull, convex_hull_plot_2d
import imageio
import numpy as np
import warnings
import torch
from torch import nn
import torch.optim as opt

# %%
tracking1=pd.read_csv('tracking_week_1.csv')
# filename = os.path.join(os.path.join("Data", str(2024)),"tracking_week_"+str(1) +".csv")
# tracking1 = pd.read_csv(filename)
# filename = os.path.join(os.path.join("Data", str(2024)),"plays.csv")
plays=pd.read_csv('plays.csv')

tracking1.loc[tracking1['playDirection'] == 'left', 'x'] = 120 - tracking1.loc[tracking1['playDirection'] == 'left', 'x']
tracking1.loc[tracking1['playDirection'] == 'left', 'y'] = (160/3) - tracking1.loc[tracking1['playDirection'] == 'left', 'y']
tracking1.loc[tracking1['playDirection'] == 'left', 'dir'] += 180
tracking1.loc[tracking1['dir'] > 360, 'dir'] -= 360
tracking1.loc[tracking1['playDirection'] == 'left', 'o'] += 180
tracking1.loc[tracking1['o'] > 360, 'o'] -= 360

tracking1_with_plays = tracking1.merge(plays, on=['gameId', 'playId'], how='left')
tracking1_with_plays = tracking1_with_plays[tracking1_with_plays['playNullifiedByPenalty'] == 'N']
tracking1_with_plays['is_on_offence'] = tracking1_with_plays['club'] == tracking1_with_plays['possessionTeam']
tracking1_with_plays['is_on_defence'] = tracking1_with_plays['club'] == tracking1_with_plays['defensiveTeam']
tracking1_with_plays['is_ballcarrier'] = tracking1_with_plays['ballCarrierId'] == tracking1_with_plays['nflId']

tracking1_with_plays
# Out:
#              gameId  playId    nflId     displayName  frameId  \
# 0        2022090800      56  35472.0  Rodger Saffold        1
# 1        2022090800      56  35472.0  Rodger Saffold        2
# 2        2022090800      56  35472.0  Rodger Saffold        3
# 3        2022090800      56  35472.0  Rodger Saffold        4
# 4        2022090800      56  35472.0  Rodger Saffold        5
# ...             ...     ...      ...             ...      ...
# 1407434  2022091200    3826      NaN        football       49
# 1407435  2022091200    3826      NaN        football       50
# 1407436  2022091200    3826      NaN        football       51
# 1407437  2022091200    3826      NaN        football       52
# 1407438  2022091200    3826      NaN        football       53
#
#                                time  jerseyNumber      club playDirection  \
# 0        2022-09-08 20:24:05.200000          76.0       BUF          left
# 1        2022-09-08 20:24:05.299999          76.0       BUF          left
# 2        2022-09-08 20:24:05.400000          76.0       BUF          left
# 3        2022-09-08 20:24:05.500000          76.0       BUF          left
# 4        2022-09-08 20:24:05.599999          76.0       BUF          left
# ...                             ...           ...       ...           ...
# 1407434  2022-09-12 23:05:57.799999           NaN  football          left
# 1407435  2022-09-12 23:05:57.900000           NaN  football          left
# 1407436  2022-09-12 23:05:58.000000           NaN  football          left
# 1407437  2022-09-12 23:05:58.099999           NaN  football          left
# 1407438  2022-09-12 23:05:58.200000           NaN  football          left
#
#                  x  ...  visitorTeamWinProbilityAdded  expectedPoints  \
# 0        31.630000  ...                      0.000031        1.298699
# 1        31.530000  ...                      0.000031        1.298699
# 2        31.440000  ...                      0.000031        1.298699
# 3        31.360000  ...                      0.000031        1.298699
# 4        31.280000  ...                      0.000031        1.298699
# ...            ...  ...                           ...             ...
# 1407434  63.779999  ...                     -0.282255        0.967420
# 1407435  63.939999  ...                     -0.282255        0.967420
# 1407436  64.110001  ...                     -0.282255        0.967420
# 1407437  64.270000  ...                     -0.282255        0.967420
# 1407438  64.430000  ...                     -0.282255        0.967420
#
#          expectedPointsAdded  foulName1  foulName2  foulNFLId1 foulNFLId2  \
# 0                   0.004420        NaN        NaN         NaN        NaN
# 1                   0.004420        NaN        NaN         NaN        NaN
# 2                   0.004420        NaN        NaN         NaN        NaN
# 3                   0.004420        NaN        NaN         NaN        NaN
# 4                   0.004420        NaN        NaN         NaN        NaN
# ...                      ...        ...        ...         ...        ...
# 1407434            -0.719924        NaN        NaN         NaN        NaN
# 1407435            -0.719924        NaN        NaN         NaN        NaN
# 1407436            -0.719924        NaN        NaN         NaN        NaN
# 1407437            -0.719924        NaN        NaN         NaN        NaN
# 1407438            -0.719924        NaN        NaN         NaN        NaN
#
#          is_on_offence is_on_defence is_ballcarrier
# 0                 True         False          False
# 1                 True         False          False
# 2                 True         False          False
# 3                 True         False          False
# 4                 True         False          False
# ...                ...           ...            ...
# 1407434          False         False          False
# 1407435          False         False          False
# 1407436          False         False          False
# 1407437          False         False          False
# 1407438          False         False          False
#
# [1370386 rows x 53 columns]

# %%
tracking1_with_plays['event'].unique()
# Out:
# array([nan, 'pass_arrived', 'pass_outcome_caught', 'tackle', 'run',
#        'first_contact', 'ball_snap', 'handoff', 'touchdown',
#        'out_of_bounds', 'man_in_motion', 'fumble', 'play_action',
#        'pass_forward', 'lateral', 'autoevent_passforward',
#        'autoevent_passinterrupted', 'line_set', 'qb_slide', 'shift',
#        'run_pass_option', 'qb_sack', 'pass_shovel', 'autoevent_ballsnap',
#        'snap_direct', 'fumble_defense_recovered',
#        'fumble_offense_recovered'], dtype=object)

# %%
def preprocessing(df, past=False):
    df['radiansDirection'] = df['dir'].astype(float).apply(math.radians) #Converts angle in degrees to radians
    df['xComponent']=df['radiansDirection'].astype(float).apply(math.cos) #Converts angle into an x and y component
    df['yComponent']=df['radiansDirection'].astype(float).apply(math.sin)
    df['xspeed']=df['xComponent']*df['s'] #Determines magnitude of speed by multiplying x and y component by magnitude of speed
    df['yspeed']=df['yComponent']*df['s']
    if past:
        df['OLD_x']=df['x']
        df['OLD_y']=df['y']
        df['OLD_xspeed']=df['xspeed']
        df['OLD_yspeed']=df['yspeed']
        df['OLD_o']=df['o']
        df['OLD_s']=df['s']
        df['OLD_dir']=df['dir']
        df['PROJ_x']=df['OLD_x']+df['OLD_xspeed']*0.1
        df['PROJ_y']=df['OLD_y']+df['OLD_yspeed']*0.1
        return df[['gameId', 'playId', 'nflId', 'OLD_x', 'OLD_y', 'OLD_s', 'OLD_o', 'OLD_dir', 'OLD_xspeed', 'OLD_yspeed', 'PROJ_x', 'PROJ_y']]
    return df

# %%
def model(df, nflId):
    if nflId==38577:
        return 1
    return 0

# %%
def reformat(frame):
    #Initilize ball carrier row
    ballcarrier = 0
    #Create empty array
    temp = torch.zeros(8,22,22)
    #Get vector of defence and offence teams
    frame['radiansDirection'] = frame['dir'].astype(float).apply(math.radians) #Converts angle in degrees to radians
    frame['xComponent']=frame['radiansDirection'].astype(float).apply(math.cos) #Converts angle into an x and y component
    frame['yComponent']=frame['radiansDirection'].astype(float).apply(math.sin)
    frame['xspeed']=frame['xComponent']*frame['s'] #Determines magnitude of speed by multiplying x and y component by magnitude of speed
    frame['yspeed']=frame['yComponent']*frame['s']
    for i in range(len(frame['x'])):
        #Assign ballcarrier if player is ballcarrier
        if frame.iloc[i]["is_ballcarrier"]:
            #print("yo")
            ballcarrier = i
            ballx = frame.iloc[i]['x']
        #Assign team vector:
        if frame.iloc[i]['is_on_offence']:
            teamvec2 = frame['is_on_offence']
        else:
            teamvec2 = frame['is_on_defence']
        #Get x,y,s,o,dir and for current player
        x1 = frame.iloc[i]['x']
        y1 = frame.iloc[i]['y']
        s1 = frame.iloc[i]['s']
        xs1 = frame.iloc[i]['xspeed']
        ys1 = frame.iloc[i]['yspeed']
        o1 = frame.iloc[i]['o']
        dir1 = frame.iloc[i]['dir']
        # Assign relative values
        temp[0,:,i] = torch.tensor((frame['x'] - x1).values)
        temp[0,i,i] = x1
        temp[1,:,i] = torch.tensor((frame['y'] - y1).values)
        temp[1,i,i] = y1
        temp[2,:,i] = torch.tensor((frame['s'] - s1).values)
        temp[2,i,i] = s1
        temp[3,:,i] = torch.tensor((frame['xspeed'] - xs1).values)
        temp[3,i,i] = xs1
        temp[4,:,i] = torch.tensor((frame['yspeed'] - ys1).values)
        temp[4,i,i] = ys1

        temp[5,:,i] = torch.tensor((np.arctan2((frame['y'] - y1).to_numpy(), -1*(frame['x'] - x1).to_numpy())*180/np.pi))
        temp[5,:,i] = temp[4,:,i] + (1*(-1*(frame['x'] - x1) > 0).values & (((frame['y'] - y1) < 0)*180).values) + (-1*(-1*(frame['x'] - x1) > 0).values & ((frame['y'] - y1) < 0).values)*180
        temp[5,:,i] = temp[4,:,i] -360*(temp[4,:,i] > 360)
        temp[5,:,i] = temp[4,:,i] +360*(temp[4,:,i] < 0)

        #orientation = temp[4,:,i]
        frame['orientation'] = temp[4,:,i].tolist()
        rads = frame['orientation'].apply(math.radians) #Converts angle in degrees to radians
        xcomp = torch.tensor(rads.apply(math.cos).tolist()) #Converts angle into an x and y component
        ycomp = torch.tensor(rads.apply(math.sin).tolist())
        temp[5,:,i] = torch.tensor((frame['s']).values)*xcomp
        temp[6,:,i] = torch.tensor((frame['s']).values)*ycomp

        #This is fine
        temp[7,:,i] = torch.tensor((teamvec2*(((frame['x'] - x1)**2 + (frame['y'] - y1)**2)**0.5) - (~teamvec2)*(((frame['x'] - x1)**2 + (frame['y'] - y1)**2)**0.5)).values)

    #Sort by player distance from ball carrier, with defensive position being negative
    inds = temp[7,ballcarrier,:].sort()[1]
    temp = temp[:,:,inds]
    temp = temp[:,inds,:]
    return temp

def reformat2(frame):
    #Initilize ball carrier row
    ballcarrier = 0
    #Create empty array
    temp = torch.zeros(8,22,22)
    #Get vector of defence and offence teams
    
    for i in range(len(frame['x'])):
        #Assign ballcarrier if player is ballcarrier
        if frame.iloc[i]["is_ballcarrier"]:
            #print("yo")
            ballcarrier = i
        #Assign team vector:
        if frame.iloc[i]['is_on_offence']:
            teamvec2 = frame['is_on_offence']
        else:
            teamvec2 = frame['is_on_defence']
        #Get x,y,s,o,dir and for current player
        x1 = frame.iloc[i]['x']
        
        y1 = frame.iloc[i]['y']
        s1 = frame.iloc[i]['s']
        o1 = frame.iloc[i]['o']
        dir1 = frame.iloc[i]['dir']
        # Assign relative values
        temp[0,i,:] = torch.tensor((frame['x'] - x1).values)
        print(temp[0,i,:])
        temp[1,i,:] = torch.tensor((frame['y'] - y1).values)
        temp[2,i,:] = torch.tensor((frame['s'] - s1).values)
        temp[3,i,:] = torch.tensor((frame['dir'] - dir1).values)
        temp[3,i,:] = temp[3,i,:] - (temp[3,i,:] > 360)*-360
        temp[3,i,:] = temp[3,i,:] + (temp[3,i,:] < 0)*-360
        temp[4,i,:] = torch.tensor((np.arctan2((frame['y'] - y1).to_numpy(), -1*(frame['x'] - x1).to_numpy())*180/np.pi))
        temp[4,i,:] = temp[4,i,:] + (1*(-1*(frame['x'] - x1) > 0).values & (((frame['y'] - y1) < 0)*180).values) + (-1*(-1*(frame['x'] - x1) > 0).values & ((frame['y'] - y1) < 0).values)*180
        temp[4,i,:] = temp[4,i,:] -360*(temp[4,i,:] > 360)
        temp[4,i,:] = temp[4,i,:] +360*(temp[4,i,:] < 0)
        temp[4,i,:] -= o1
        #This is fine
        temp[5,:,i] = torch.tensor((teamvec2*(((frame['x'] - x1)**2 + (frame['y'] - y1)**2)**0.5) - (~teamvec2)*(((frame['x'] - x1)**2 + (frame['y'] - y1)**2)**0.5)).values)
        # Get distance from sideline and goalline
        if y1 >= 53.3/2:
            temp[6,:,i] = 53.3 - y1
        else:
            temp[6,:,i] = y1
                                    
        temp[7,:,i] = 105 - x1
    #Sort by player distance from ball carrier, with defensive position being negative
    inds = temp[5,ballcarrier,:].sort()[1]
    temp = temp[:,:,inds]
    temp = temp[:,inds,:]
    return temp

def predict(frame,model):
    #seperate predicted yards and attention mechanism
    frame = torch.unsqueeze(reformat(frame),0)
    #print(frame[0,0,1])
    yards_predict, att = model.forward(frame)
    #return predicted yards
    #print(yards_predict)
    return yards_predict.detach().item()

# %%
class AttentionBlock(nn.Module):
    def __init__(self, in_features_l, in_features_g, attn_features, up_factor, normalize_attn=True):
        super(AttentionBlock, self).__init__()
        self.up_factor = up_factor
        self.normalize_attn = normalize_attn
        self.W_l = nn.Conv2d(in_channels=in_features_l, out_channels=attn_features, kernel_size=1, padding=0, bias=False)
        self.W_g = nn.Conv2d(in_channels=in_features_g, out_channels=attn_features, kernel_size=1, padding=0, bias=False)
        self.phi = nn.Conv2d(in_channels=attn_features, out_channels=1, kernel_size=1, padding=0, bias=True)
        self.relu = nn.SiLU()
    def forward(self, l, g):
        #print(in_features_g)
        N, C, W, H = l.shape
        l_ = self.W_l(l)
        g_ = self.W_g(g)
        #print(g_.shape)
        c = self.phi(self.relu(l_ + g_)) # batch_sizex1xWxH
        #print(c.shape)
        # compute attn map
        if self.normalize_attn:
            a = (c.view(N,1,-1)).view(N,1,W,H)
        else:
            a = torch.sigmoid(c)
        # re-weight the local feature
        f = torch.mul(a.expand_as(l), l) # batch_sizexCxWxH
        if self.normalize_attn:
            output = f.view(N,C,-1) # weighted sum
        else:
            output = nn.AdaptiveAvgPool2d(f, (1,1)).view(N,C) # global average pooling
        return a, output
    
class Skynet1_4(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv21 = nn.Conv2d(8,128,1,stride = 1)
        self.conv22 = nn.Conv2d(128, 160, 1,stride = 1)
        self.conv23 = nn.Conv2d(160,128, 1,stride = 1)
        self.poolmax2 = nn.MaxPool2d(1,5)
        self.poolavg2 = nn.AvgPool2d(1,5)

        self.poolmax1 = nn.MaxPool1d(1,5)
        self.poolavg1 = nn.AvgPool1d(1,5)
        self.batch1 = nn.BatchNorm1d(2)

        self.conv11 = nn.Conv1d(2,128,1)
        self.batch2 = nn.BatchNorm1d(128)
        self.conv12 = nn.Conv1d(128,160,1)
        self.batch3 = nn.BatchNorm1d(160)
        self.conv13 = nn.Conv1d(160,96,1)
        self.batch4 = nn.BatchNorm1d(96)

        self.attentionmech = AttentionBlock(8, 128, 256, 4, normalize_attn=True)
        self.fc1 = nn.Linear(1920,512)
        self.fc2 = nn.Linear(512,256)
        self.batch6 = nn.BatchNorm1d(512)
        self.batch5 = nn.BatchNorm1d(256)
        self.fc3 = nn.Linear(256,1)
        #self.squeeze = torch.squeeze(1)
        self.relu = nn.SiLU()

    def forward(self,x):
        temp = x
        x = self.relu(self.conv21(x))
        x = self.relu(self.conv22(x))
        x = self.relu(self.conv23(x))
        attention, x = self.attentionmech(temp,x)
        xmax = self.poolmax2(x)
        xavg = self.poolavg2(x)
        x = 0.3*xmax + 0.7*xavg
        #print(x.shape)
        
        #x = torch.flatten(x,start_dim=2,end_dim=3)
        x = self.batch1(x)
        x = self.relu(self.conv11(x))
        x = self.batch2(x)
        x = self.relu(self.conv12(x))
        x = self.batch3(x)
        x = self.relu(self.conv13(x))
        x = self.batch4(x)
        xmax = self.poolmax1(x)
        xavg = self.poolavg1(x)
        x = 0.3*xmax + 0.7*xavg
        x = torch.flatten(x,start_dim=1,end_dim=2)
        #print(x.shape)

        x = self.relu(self.fc1(x))
        #print(x.mT.shape)
        x = self.batch6(x)
        x = self.relu(self.fc2(x))
        #x = self.batch5(x.T)
        x = self.fc3(x)
        return x, attention

# %%
#Load the model, requires load file to be in same directory
device = "cpu"
model = Skynet1_4().to(device).eval()
model.load_state_dict(torch.load("modelSkynet15-5.pt", map_location=device))
# Out:
# <All keys matched successfully>

# %%
def generate_counter_factuals(tracking, gameId, playId, time, prev_locations):
    tracking_single=tracking.loc[(tracking['playId'] == playId) & (tracking['time']==time) & (tracking['gameId']==gameId) & (tracking['nflId'].isna()==False)]
    tracking_single=preprocessing(tracking_single)
    tracking_single=tracking_single.merge(prev_locations, how='inner', on=['gameId', 'playId', 'nflId'])
    defensive_ids=tracking_single.loc[tracking_single['is_on_defence']==True]['nflId']
    tracking_single['yards_saved']=0
    #print(tracking_single[['x', 'y', 's', 'dir', 'o', 'is_on_offence', 'is_on_defence', 'is_ballcarrier']].iloc[0])
    #print(tracking_single['x'])
    regular_prediction=predict(tracking_single[['x', 'y', 's', 'dir', 'o', 'is_on_offence', 'is_on_defence', 'is_ballcarrier']], model)
    print(regular_prediction)
    #print(regular_prediction)
    for i in defensive_ids:
        passed_df=tracking_single.copy()
        list_values=list(passed_df.loc[passed_df['nflId']==i].iloc[0][['PROJ_x', 'PROJ_y', 'OLD_s', 'OLD_dir', 'OLD_o']])
        passed_df.loc[passed_df['nflId']==i, ['x', 'y', 's', 'dir', 'o']]=list_values
        temp = predict(passed_df[['x', 'y', 's', 'dir', 'o', 'is_on_offence', 'is_on_defence', 'is_ballcarrier']], model)-regular_prediction
        #print(temp)
        tracking_single.loc[tracking_single['nflId']==i, 'yards_saved']=temp
    return tracking_single.loc[tracking_single['is_on_defence']==True][['nflId', 'displayName', 'jerseyNumber', 'yards_saved']]

# %%
def generate_counter_factual_movements(tracking, gameId, playId):
    tracking['time']=pd.to_datetime(tracking['time'])
    try:
        handoff_time=tracking.loc[(tracking['playId'] == playId)& (tracking['gameId']==gameId) & (tracking['event'].isin(['pass_arrived','handoff']))]['time'].unique()[0]
        play_info=tracking.loc[(tracking['playId'] == playId) & (tracking['gameId']==gameId) & (tracking['time']>handoff_time)]
    except:
        play_info=tracking.loc[(tracking['playId'] == playId)  & (tracking['gameId']==gameId)]
    try:
        tackle_time=tracking1_with_plays.loc[(tracking1_with_plays['playId'] == playId)& (tracking1_with_plays['gameId']==gameId) & (tracking1_with_plays['event'].isin(['tackle', 'out_of_bounds']))]['time'].unique()[0]
        play_info=play_info.loc[(play_info['playId'] == playId) & (play_info['gameId']==gameId) & (play_info['time']<tackle_time)]
    except:
        play_info.loc[(play_info['playId'] == playId) & (play_info['gameId']==gameId)]
    distinctTimes=play_info['time'].unique()
    previous_defense_time=distinctTimes[0]
    savedTable={}
    for i in range(1, len(distinctTimes[1:])):
        prev_location=tracking.loc[(tracking['playId'] == playId) & (tracking['time']==previous_defense_time) & (tracking['gameId']==gameId)]
        prev_location=preprocessing(prev_location, True) 
        #print(tracking['x'])
        dfForRunning=generate_counter_factuals(tracking, gameId, playId, distinctTimes[i], prev_location)
        if i==1:
            savedTable=dfForRunning
        else:
            savedTable=savedTable.merge(dfForRunning, how='outer', on=['nflId','displayName', 'jerseyNumber'], suffixes=('_table1', '_table2'))
            savedTable['yards_saved']=savedTable['yards_saved_table1']+savedTable['yards_saved_table2']
            savedTable=savedTable[['nflId', 'displayName', 'jerseyNumber', 'yards_saved']]
        previous_defense_time=distinctTimes[i]
    return savedTable

# %%
warnings.filterwarnings('ignore')

generate_counter_factual_movements(tracking1_with_plays, 2022090800, 818)
# Out:
# 1.9996435642242432
# 2.2792210578918457
# 2.479606866836548
# 3.108947992324829
# 3.0135140419006348
# 2.795105457305908
# 2.418433904647827
# 2.258922576904297
# 2.113607406616211
# 2.1154940128326416
# 2.052961826324463
# 1.7700140476226807
# 1.5303051471710205
# 1.4655547142028809
# 1.2053425312042236
# 1.112149953842163
# 0.9967113137245178
# 0.7957683205604553
# 0.7480989098548889
# 0.6253640055656433
#       nflId        displayName  jerseyNumber  yards_saved
# 0   37075.0         Von Miller          40.0     0.177490
# 1   40107.0         Micah Hyde          23.0     0.382201
# 2   40166.0       Jordan Poyer          21.0     0.491714
# 3   42395.0    Jordan Phillips          97.0     0.196933
# 4   44976.0        Matt Milano          58.0     0.992772
# 5   46085.0   Tremaine Edmunds          49.0    10.683898
# 6   46190.0      Taron Johnson           7.0     3.102438
# 7   47792.0          Ed Oliver          91.0     0.049448
# 8   52647.0       Dane Jackson          30.0     2.623584
# 9   53459.0   Gregory Rousseau          50.0     0.208008
# 10  54650.0  Christian Benford          47.0     0.322348

# %%
tracking1_with_plays['time']=pd.to_datetime(tracking1_with_plays['time'])
handoff_time=tracking1_with_plays.loc[(tracking1_with_plays['playId'] == 56)& (tracking1_with_plays['gameId']==2022090800) & (tracking1_with_plays['event'].isin(['pass_arrived','handoff']))]['time'].unique()[0]
tackle_time=tracking1_with_plays.loc[(tracking1_with_plays['playId'] == 56)& (tracking1_with_plays['gameId']==2022090800) & (tracking1_with_plays['event'].isin(['tackle', 'out_of_bounds']))]['time'].unique()[0]

tracking1_with_plays.loc[(tracking1_with_plays['playId'] == 56)& (tracking1_with_plays['gameId']==2022090800) & (tracking1_with_plays['time']>handoff_time) & (tracking1_with_plays['time']<tackle_time)]['gameClock']
# Out:
# 2      15:00
# 3      15:00
# 4      15:00
# 5      15:00
# 6      15:00
#        ...
# 496    15:00
# 497    15:00
# 498    15:00
# 499    15:00
# 500    15:00
# Name: gameClock, Length: 345, dtype: object

# %%
def processToVisualize(tracking, play, game_info, gameId, playId, time):
  tracking_single=tracking.loc[(tracking['playId'] == playId) & (tracking['time']==time) & (tracking['gameId']==gameId)]
  testingNew=pd.merge(tracking_single, play, on=['gameId', 'playId'], how='inner')
  testingNew=pd.merge(testingNew, game_info, on=['gameId'], how='inner')
  testingNew['radiansDirection'] = testingNew['dir'].astype(float).apply(math.radians) #Converts angle in degrees to radians
  testingNew['xComponent']=testingNew['radiansDirection'].astype(float).apply(math.cos) #Converts angle into an x and y component
  testingNew['yComponent']=testingNew['radiansDirection'].astype(float).apply(math.sin)
  testingNew['xspeed']=testingNew['xComponent']*testingNew['s'] #Determines magnitude of speed by multiplying x and y component by magnitude of speed
  testingNew['yspeed']=testingNew['yComponent']*testingNew['s']
  return testingNew

# %%
tracking1_with_plays.loc[(tracking1_with_plays['gameId']==2022090800)]['playId'].unique()
# Out:
# array([  56,   80,  101,  122,  146,  167,  191,  212,  236,  299,  343,
#         364,  393,  414,  438,  486,  529,  569,  593,  617,  646,  692,
#         775,  818,  867,  896,  933,  980, 1030, 1102, 1187, 1230, 1254,
#        1286, 1334, 1358, 1385, 1406, 1563, 1712, 1736, 1757, 1836, 1946,
#        1967, 2043, 2072, 2093, 2137, 2163, 2184, 2208, 2232, 2307, 2336,
#        2360, 2464, 2485, 2506, 2527, 2551, 2572, 2599, 2648, 2688, 2712,
#        2755, 2815, 2839, 2860, 2884, 2934, 2958, 2979, 3092, 3121, 3145,
#        3166, 3190, 3262, 3283, 3304, 3341, 3362, 3383, 3407, 3431, 3489,
#        3513, 3576, 3636])

# %%
tracking1_with_plays.loc[(tracking1_with_plays['playId'] == 818)& (tracking1_with_plays['gameId']==2022090800)]['gameClock']
# Out:
# 17779    15:00
# 17780    15:00
# 17781    15:00
# 17782    15:00
# 17783    15:00
#          ...
# 18464    15:00
# 18465    15:00
# 18466    15:00
# 18467    15:00
# 18468    15:00
# Name: gameClock, Length: 690, dtype: object
